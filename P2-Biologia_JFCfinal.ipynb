# %% [markdown]
# # PRACTICA 2
#
# ### ¡Con todo lo aprendido con Python, vamos a resolver unos ejercicios de Bioinformática!
#
# #### 1.- Concatena las cadenas ATGCC y TCCG

# %%
cadena1 = "ATGCC"
cadena2 = "TCCG"

# %%
resultado = cadena1 + cadena2
print(resultado)
# Out:
# ATGCCTCCG

# %% [markdown]
# #### 2.- ¿Cuál es la longitud de ATGCGAGT?

# %%
dna="ATGCGAGT"

# %%
longitud=len(dna)
print(longitud)
# Out:
# 8

# %% [markdown]
# #### 3.- Con la cadena mgXDyTw, ponla en mayúsculas, luego en minúsculas. Extrae su longitud y divide la cadena por la letra "g"

# %%
cadena="mgXDyTw"

# %%
#En mayusculas
mayuscula= cadena.upper()
print("Mayusculas:",mayuscula)
# Out:
# Mayusculas: MGXDYTW

# %%
#En minusculas
minuscula= cadena.lower()
print("Minusculas:",minuscula)
# Out:
# Minusculas: mgxdytw

# %%
#Longitud
longitud=len(cadena)
print("Longitud:",longitud)
# Out:
# Longitud: 7

# %%
#Dividir la cadena por la letra g
cadividida= cadena.split("g")
print("Dividida por g:",cadividida)
# Out:
# Dividida por g: ['m', 'XDyTw']

# %% [markdown]
# #### 4.- Con la secuencia de aminoácidos vlspadktnv, reemplaza la valina con la tirosina. Pista: usa replace()

# %%
aa = "vlspadktnv"

# %%
secuencia= "vlspadktnv"
secuencia_nueva= secuencia.replace("v","y")

print("Original:",secuencia)
print("Modificada:",secuencia_nueva)
# Out:
# Original: vlspadktnv
# Modificada: ylspadktny

# %% [markdown]
# #### 5.- Cuenta las valinas de la secuencia original anterior.

# %%
num_valinas= secuencia.count("v")
print("Numero de valinas:",num_valinas)
# Out:
# Numero de valinas: 2

# %% [markdown]
# #### 6.- Con el diccionario siguiente imprime el valor de BisI y saca el valor de EcoRI con pop(). ¿Qué pasa con el diccionario?

# %%
enzR = {
    'EcoRI':r'GAATTC',
    'AvaII':r'GG(A|T)CC',
    'BisI':r'GC[ATGC]GC'
}

# %%
print("Valor de BisI:", enzR["BisI"])
# Out:
# Valor de BisI: GC[ATGC]GC

# %%
valor_ecori= enzR.pop("EcoRI")
print("Valor de EcoRI:", valor_ecori)
# Out:
# Valor de EcoRI: GAATTC

# %%
print("Diccionario despues de pop:", enzR)
# Out:
# Diccionario despues de pop: {'AvaII': 'GG(A|T)CC', 'BisI': 'GC[ATGC]GC'}

# %% [markdown]
# #### 7.- Con la secuencia y la lista siguiente, escribe un algoritmo que cuente el número de veces que aparece un elemento de la lista en la secuencia. Pista: hacer un diccionario para almacenar los resultados puede ser buena idea

# %%
dna = "AATGATGAACGAC" 
dinucleotides = ['AA','AT','AG','AC', 
                 'TA','TT','TG','TC', 
                 'GA','GT','GG','GC', 
                 'CA','CT','CG','CC']

# %%
conteo={}
for d in dinucleotides:
    conteo[d] = dna.count(d)

print(conteo)
# Out:
# {'AA': 2, 'AT': 2, 'AG': 0, 'AC': 2, 'TA': 0, 'TT': 0, 'TG': 2, 'TC': 0, 'GA': 3, 'GT': 0, 'GG': 0, 'GC': 0, 'CA': 0, 'CT': 0, 'CG': 1, 'CC': 0}

# %% [markdown]
# ##### ¿Cuántos counts tiene TC?

# %%
dna.count("TC")
# Out:
# 0

# %% [markdown]
# ##### ¿Puedes imprimir los dinuleótidos que tengan counts igual a 2?

# %%
for d, c in conteo.items():
    if c==2:
        print(d,"→",c)
# Out:
# AA → 2
# AT → 2
# AC → 2
# TG → 2
