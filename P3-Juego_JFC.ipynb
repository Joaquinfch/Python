# %% [markdown]
# # PRACTICA 3
#
#
# ## JUEGO DE ADIVINANZAS
#
# #### Escribe un programa que coja un número entero del 1 al 100, y los jugadores tienen que tratar de adivinar el número.
#
# #### Las reglas son las siguientes:
#
# 1. Si un jugador escoje un número menor que 1 o mayor que 100, el programa dice "FUERA DE LÍMITES"
# 2. En el primer turno del jugador, si está en un rango de 10 del número dice "¡CALIENTE!". Si está fuera de ese rango dice "¡FRIO!"
# 3. En todas las rondas siguientes, si el jugador se acerca más que la vez anterior, dice "¡MAS CALIENTE!". Si está más lejos que la anterior vez dice "¡MAS FRIO!"
# 4. Cuando el jugador acierte el número, les dirá que han acertado y cuántos intentos les ha llevado

# %% [markdown]
# ##### PISTAS
# 1. Trata obtener un número aleatorio entre el 1 y el 100
# 2. Haz una introducción de tu juego y explica las reglas
# 3. Crea una lista que almacene los intentos.
# 4. Haz un bucle que evalúe un número. Prueba que funcione primero. While podría ir bien
# 5. Modifica ese bucle para que compare nuestro número con el intento. Si se acierta usa break, si no puedes usar continue y tienes que seguir preguntando al jugador por nuevos intentos

# %%
print("¡Bienvenido a frio o caliente!")
print("En este juego tienes que adivinar que numero del 1 al 100 estoy pensando")
print("Las reglas son las siguientes:")
print("-Tu numero debe estar entre el 1 y el 100, si no, esta FUERA DE LIMITES")
print("-Si en tu primer intento estas a 10 numeros → CALIENTE, si no, → FRIO")
print("-Los siguientes intentos, si te acercas → MAS CALIENTE, si te alejas → MAS FRIO")
print("¡El juego terminara cuando aciertes el numero!")

import random

numero= random.randint(1, 100)

intentos=[]

while True:
    try: 
        intento=int(input("Elige tu numero:"))
    except ValueError:
        print("Debes ingresar un numero entero.")
        continue

    if intento < 1 or intento > 100:
        print("Debe estar entre 1-100.")
        continue

       #para guardar intentos
    intentos.append(intento)

    if intento == numero: 
            print(f"¡Correcto! El numero era {numero}.")
            print(f"Lo lograste en {len(intentos)} intentos.")
            break

    if len(intentos) == 1:
        if abs(numero-intento)<= 10:
            print("¡CALIENTE!")
        else:
            print("¡FRIO!")

    else:
        if abs(numero-intento) < abs(numero-intentos[-2]):
            print("¡MAS CALIENTE!")
        else:
            print("¡MAS FRIO!")
# Out:
# ¡Bienvenido a frio o caliente!
# En este juego tienes que adivinar que numero del 1 al 100 estoy pensando
# Las reglas son las siguientes:
# -Tu numero debe estar entre el 1 y el 100, si no, esta FUERA DE LIMITES
# -Si en tu primer intento estas a 10 numeros → CALIENTE, si no, → FRIO
# -Los siguientes intentos, si te acercas → MAS CALIENTE, si te alejas → MAS FRIO
# ¡El juego terminara cuando aciertes el numero!
# Elige tu numero: 7
# ¡FRIO!
# Elige tu numero: 2
# ¡MAS FRIO!
# Elige tu numero: 9
# ¡MAS CALIENTE!
# Elige tu numero: 99
# ¡MAS FRIO!
# Elige tu numero: 50
# ¡MAS CALIENTE!
# Elige tu numero: 56
# ¡MAS FRIO!
# Elige tu numero: 40
# ¡MAS CALIENTE!
# Elige tu numero: 30
# ¡MAS CALIENTE!
# Elige tu numero: 20
# ¡MAS CALIENTE!
# Elige tu numero: 15
# ¡MAS FRIO!
# Elige tu numero: 21
# ¡MAS CALIENTE!
# Elige tu numero: 22
# ¡MAS FRIO!
# Elige tu numero: 19
# ¡Correcto! El numero era 19.
# Lo lograste en 13 intentos.
